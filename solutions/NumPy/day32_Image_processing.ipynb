# %% [markdown]
# ## Challenge: Load an image as a NumPy array and perform image processing tasks like cropping, resizing, color adjustments, and filtering using NumPy functions.

# %% [markdown]
# ## Importing libraies

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading an image

# %%
image1 = plt.imread('new01.jpg')
image1
# Out:
# array([[[ 26,  38,  38],
#         [ 26,  38,  38],
#         [ 26,  38,  38],
#         ...,
#         [ 15,  21,  21],
#         [ 17,  21,  22],
#         [251, 255, 255]],
#
#        [[ 26,  38,  38],
#         [ 26,  38,  38],
#         [ 26,  38,  38],
#         ...,
#         [ 15,  21,  21],
#         [ 17,  21,  22],
#         [251, 255, 255]],
#
#        [[ 26,  38,  38],
#         [ 26,  38,  38],
#         [ 26,  38,  38],
#         ...,
#         [ 15,  21,  21],
#         [ 17,  21,  22],
#         [251, 255, 255]],
#
#        ...,
#
#        [[ 52,  21,  37],
#         [ 57,  24,  43],
#         [ 58,  24,  48],
#         ...,
#         [135, 133, 144],
#         [131, 130, 138],
#         [255, 254, 255]],
#
#        [[ 56,  28,  40],
#         [ 59,  31,  43],
#         [ 62,  31,  47],
#         ...,
#         [111, 110, 116],
#         [124, 123, 129],
#         [244, 243, 248]],
#
#        [[255, 252, 252],
#         [255, 253, 253],
#         [255, 252, 255],
# ...

# %%
image1.shape
# Out:
# (407, 229, 3)

# %% [markdown]
# ## Using matplotlib we can able to see the image

# %%
plt.imshow(image1)
plt.show()

# %% [markdown]
# ## Cropping

# %%
cropimg = image1[75:350,120:400,:]    
imgplot = plt.imshow(cropimg)

# %% [markdown]
# ## Importing one more image to do operations

# %% [markdown]
# ## While doing arthimetic operations or any other operations in two images broadcasting condition must be satisfied

# %% [markdown]
# Arrays have the same number of dimensions (rank)
#
# Arrays have the same shape or one of them has a size of 1

# %%
image2 = plt.imread('new02.jpg')

# %%
plt.imshow(image2)
plt.show()

# %% [markdown]
# # Arithmetic Operations

# %%
plt.imshow(image1+image2)
plt.show()

# %% [markdown]
# ## Rotating the image to 90 degrees

# %%
plt.imshow(np.rot90(image2))
plt.show()

# %% [markdown]
# ## Negative image

# %%
plt.imshow(-image2)
plt.show()

# %% [markdown]
# ## Still lot to cover in image processing we will see in future
