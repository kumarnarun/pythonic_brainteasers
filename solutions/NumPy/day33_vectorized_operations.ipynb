# %% [markdown]
# ## Implement a vectorized function using NumPy to calculate a mathematical operation for each element of an array efficiently.

# %% [markdown]
# Vectorized functions in NumPy are designed to perform element-wise operations on arrays efficiently.
#
# By using vectorized operations, you can avoid explicit loops and take advantage of NumPy's optimized C-based computations.

# %% [markdown]
# ## Importing pandas and numpy library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading my file

# %%
df = pd.read_csv('tn_tomato_price.csv')
df.head()
# Out:
#          date      admin1             admin2           market  price  usdprice
# 0  2012-04-15  Tamil Nadu            Chennai          Chennai  18.78      0.36
# 1  2012-04-15  Tamil Nadu           Dindigul         Dindigul  21.61      0.42
# 2  2012-04-15  Tamil Nadu  Tiruchchirappalli  Thiruchirapalli  21.17      0.41
# 3  2012-07-15  Tamil Nadu            Chennai          Chennai  25.77      0.47
# 4  2012-07-15  Tamil Nadu           Dindigul         Dindigul  24.18      0.44

# %% [markdown]
# ## I am gonna create a ratio column of price and usdprice using vectorized function

# %% [markdown]
# ## pandas vectorization

# %%
# %timeit df['ratio'] = df['price'] / df['usdprice']
# Out:
# 121 µs ± 949 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
df
# Out:
#            date      admin1               admin2           market  price  \
# 0    2012-04-15  Tamil Nadu              Chennai          Chennai  18.78
# 1    2012-04-15  Tamil Nadu             Dindigul         Dindigul  21.61
# 2    2012-04-15  Tamil Nadu    Tiruchchirappalli  Thiruchirapalli  21.17
# 3    2012-07-15  Tamil Nadu              Chennai          Chennai  25.77
# 4    2012-07-15  Tamil Nadu             Dindigul         Dindigul  24.18
# ..          ...         ...                  ...              ...    ...
# 357  2021-07-15  Tamil Nadu             Dindigul         Dindigul  19.71
# 358  2021-07-15  Tamil Nadu       Ramanathapuram   Ramanathapuram  23.92
# 359  2021-07-15  Tamil Nadu    Tiruchchirappalli  Thiruchirapalli  19.74
# 360  2021-07-15  Tamil Nadu  Tirunelveli Kattabo      Tirunelveli  20.30
# 361  2021-07-15  Tamil Nadu              Vellore          Vellore  17.74
#
#      usdprice      ratio
# 0        0.36  52.166667
# 1        0.42  51.452381
# 2        0.41  51.634146
# 3        0.47  54.829787
# 4        0.44  54.954545
# ..        ...        ...
# 357      0.26  75.807692
# 358      0.32  74.750000
# 359      0.26  75.923077
# 360      0.27  75.185185
# 361      0.24  73.916667
#
# [362 rows x 7 columns]

# %% [markdown]
# ## Numpy vectorization

# %%
# %timeit df['ratio_num'] = df['price'].to_numpy() / df['usdprice'].to_numpy()
# Out:
# 69.7 µs ± 2.3 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
df
# Out:
#            date      admin1               admin2           market  price  \
# 0    2012-04-15  Tamil Nadu              Chennai          Chennai  18.78
# 1    2012-04-15  Tamil Nadu             Dindigul         Dindigul  21.61
# 2    2012-04-15  Tamil Nadu    Tiruchchirappalli  Thiruchirapalli  21.17
# 3    2012-07-15  Tamil Nadu              Chennai          Chennai  25.77
# 4    2012-07-15  Tamil Nadu             Dindigul         Dindigul  24.18
# ..          ...         ...                  ...              ...    ...
# 357  2021-07-15  Tamil Nadu             Dindigul         Dindigul  19.71
# 358  2021-07-15  Tamil Nadu       Ramanathapuram   Ramanathapuram  23.92
# 359  2021-07-15  Tamil Nadu    Tiruchchirappalli  Thiruchirapalli  19.74
# 360  2021-07-15  Tamil Nadu  Tirunelveli Kattabo      Tirunelveli  20.30
# 361  2021-07-15  Tamil Nadu              Vellore          Vellore  17.74
#
#      usdprice      ratio  ratio_num
# 0        0.36  52.166667  52.166667
# 1        0.42  51.452381  51.452381
# 2        0.41  51.634146  51.634146
# 3        0.47  54.829787  54.829787
# 4        0.44  54.954545  54.954545
# ..        ...        ...        ...
# 357      0.26  75.807692  75.807692
# 358      0.32  74.750000  74.750000
# 359      0.26  75.923077  75.923077
# 360      0.27  75.185185  75.185185
# 361      0.24  73.916667  73.916667
#
# [362 rows x 8 columns]

# %% [markdown]
# ## Same operation but two different methods. Both are vectorized methods but you can the speed difference between them converting to numpy array and doing operations is the fastest
